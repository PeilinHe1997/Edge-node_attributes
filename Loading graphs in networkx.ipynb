# %%
import networkx as nx
import numpy as np
import pandas as pd

# %%
G1 = nx.Graph()
G1.add_edges_from([(0,1),(0,2),(0,3),(0,5),(1,3),(1,6),(3,4),(4,5),
                  (4,7),(5,8),(8,9)])

nx.draw_networkx(G1)
# Out:
# <img src="data:image/png;base64,..." width="862.9630239248646">

# %% [markdown]
# ## Adjacency List

# %%
G_adjlist = open(r"G_adjlist.txt","a")
for line in nx.generate_adjlist(G1):
    print(line)
    G_adjlist.write(line+"\n")
G_adjlist.close()
# Out:
# 0 1 2 3 5
# 1 3 6
# 2
# 3 4
# 5 4 8
# 6
# 4 7
# 7
# 8 9
# 9

# %%
G2 = nx.read_adjlist("G_adjlist.txt",nodetype = int)
G2.edges()
# Out:
# EdgeView([(0, 1), (0, 2), (0, 3), (0, 5), (1, 3), (1, 6), (3, 4), (5, 4), (5, 8), (4, 7), (8, 9)])

# %% [markdown]
# ## Adjacency Matrix

# %%
G_mat = np.array([[0,0,1],[1,0,0],[1,1,0]])
G3 = nx.Graph(G_mat)
G3.edges()
# Out:
# EdgeView([(0, 2), (0, 1), (1, 2)])

# %% [markdown]
# ## Edgelist

# %%
G_edgelist = open(r"G_edgelist.txt","a")
edgelist = ["0 1 4",
"0 2 5",
"0 3 2",
"0 5 6",
"1 3 2",
"1 6 5",
"3 4 3",
"5 4 1",
"5 8 2",
"4 7 6",
"8 9 1"]
for i in edgelist:
    G_edgelist.write(i+"\n")
G_edgelist.close()

# %%
G4 = nx.read_edgelist("G_edgelist.txt",data = [("weigt",int)])

# %%
G4.edges(data = True)
# Out:
# EdgeDataView([('0', '1', {'weigt': 4}), ('0', '2', {'weigt': 5}), ('0', '3', {'weigt': 2}), ('0', '5', {'weigt': 6}), ('1', '3', {'weigt': 2}), ('1', '6', {'weigt': 5}), ('3', '4', {'weigt': 3}), ('5', '4', {'weigt': 1}), ('5', '8', {'weigt': 2}), ('4', '7', {'weigt': 6}), ('8', '9', {'weigt': 1})])

# %% [markdown]
# ## Pandas DataFrame

# %%
G_df = pd.read_csv("G_edgelist.txt",delim_whitespace = True, header = None, names = ["n1","n2","weight"])

G_df
# Out:
#     n1  n2  weight
# 0    0   1       4
# 1    0   2       5
# 2    0   3       2
# 3    0   5       6
# 4    1   3       2
# 5    1   6       5
# 6    3   4       3
# 7    5   4       1
# 8    5   8       2
# 9    4   7       6
# 10   8   9       1

# %%
G5 = nx.from_pandas_edgelist(G_df,"n1","n2",edge_attr = "weight")
nx.draw_networkx(G5)
# Out:
# <img src="data:image/png;base64,..." width="862.9630239248646">
